# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import bar_chart_race as bcr

# %%
x=pd.read_csv('Countries Population from 1995 to 2020.csv')


x.head()
# Out:
#    Year Country  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0  2020   China  1439323776             0.39        5540090       -348399.0
# 1  2019   China  1433783686             0.43        6135900       -348399.0
# 2  2018   China  1427647786             0.47        6625995       -348399.0
# 3  2017   China  1421021791             0.49        6972440       -348399.0
# 4  2016   China  1414049351             0.51        7201481       -348399.0
#
#    Median Age  Fertility Rate Density (P/Km²)  Urban Pop %  Urban Population  \
# 0        38.4            1.69             153         60.8       875075919.0
# 1        37.0            1.65             153         59.7       856409297.0
# 2        37.0            1.65             152         58.6       837022095.0
# 3        37.0            1.65             151         57.5       816957613.0
# 4        37.0            1.65             151         56.3       796289491.0
#
# ...

# %%
x.isnull().sum()
# Out:
# Year                                0
# Country                             0
# Population                          0
# Yearly % Change                     0
# Yearly Change                       0
# Migrants (net)                    595
# Median Age                        595
# Fertility Rate                    595
# Density (P/Km²)                     0
# Urban Pop %                       113
# Urban Population                  113
# Country's Share of World Pop %      0
# World Population                    0
# Country Global Rank                 0
# dtype: int64

# %%
x.shape
# Out:
# (4195, 14)

# %%
x=x.reindex(columns=['Year','Population','Country'])

# %%
final_x=x.pivot_table('Population',['Year'],'Country')

# %%
final_x.head()
# Out:
# Country  Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# Year
# 1955       8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960       8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965       9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970      11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975      12689160.0  2411732.0  16607707.0         30052.0  30705.0
#
# Country     Angola  Anguilla  Antigua and Barbuda   Argentina    Armenia  ...  \
# Year                                                                      ...
# 1955     5043247.0    5783.0              49648.0  18789418.0  1563507.0  ...
# 1960     5454933.0    6032.0              54131.0  20481779.0  1874121.0  ...
# 1965     5770570.0    6361.0              58698.0  22159650.0  2211319.0  ...
# 1970     5890365.0    6771.0              64177.0  23880561.0  2525068.0  ...
# ...

# %%
x.columns
# Out:
# Index(['Year', 'Population', 'Country'], dtype='object')

# %%
bcr.bar_chart_race(df=final_x, n_bars =6, figsize =(5, 3), bar_size=0.5, filename = None)
# Out:
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 127 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 129 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 130 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 131 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
